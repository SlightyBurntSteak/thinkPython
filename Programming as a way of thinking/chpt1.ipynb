# %% [markdown]
# # Arithmetic operatiors

# %% [markdown]
# These are symbols that represent an arithmetic computation. For emaple, the + performs addition.

# %%
55 + 12
# Out:
# 67

# %%
# The - sign is for subtraction
79 - 12
# Out:
# 67

# %%
# The * sign is to perform multiplication
6 * 7
# Out:
# 42

# %%
# The / symbol is used for division
134 / 2
# Out:
# 67.0

# %% [markdown]
# ### When you divide in Python, the answer will always be a data type called a float.

# %% [markdown]
# #### Integer - represents numbers with no fractional or decimal part

# %% [markdown]
# #### Float-point numbers - represent numbers with a decimal or fractional value

# %%
# The // symbol stands for Floor Division (Integer Division)
84 // 2
# Out:
# 42

# %% [markdown]
# #### Floor Division gives you everything before the decimal.

# %%
85 / 2
# Out:
# 42.5

# %%
85 // 2
# everything from the decimal on gets removed from our answer.
# Out:
# 42

# %%
# The ** symbol is used to represent exponents
7 ** 2
# Out:
# 49

# %%
10 ** 325
# Out:
# 

# %%
# The ^ symbol (the caret), in Python it is a bitwise operator called XOR
7 ^ 2
# Out:
# 5

# %%
# The % symbol is used for what we call Modulus Division
85 % 2
# Out:
# 1

# %% [markdown]
# ## 1.2 Expressions

# %% [markdown]
# Expression - A collection of operators and numbers is called an expression
#
# example:
# 6 + 6 ** 2
# 12 ** 2
# 42
#
# (12 + 5) * 6
# 17 * 6
# 102
#
# myVar = var1 * var2 + var3
#
# ## 1.3 Arithmetic functions

# %% [markdown]
# Python is a modular language:
# * Core Python Code
# * External Modules - imported into scripts
# import math
#
# Python like any programming language has built-functions
#
# **round()** - this functions takes a floating-point number and rounds it off to the nearest integer

# %%
round(42.4)
# Out:
# 42

# %%
round(42.6)
# Out:
# 43

# %% [markdown]
# abs() function - computes the absoute value of a number

# %%
abs(42)
# Out:
# 42

# %%
abs(-42)
# Out:
# 42

# %% [markdown]
# #### Calling a function / Function call

# %% [markdown]
# The process of using a function within your code
#
# Whenever you call a function, the parathesis are required!

# %%
abs 42
# Out:
#   Cell In[5], line 1
#     abs 42
#         ^
# SyntaxError: invalid syntax

# %%
abs
# Out:
# <function abs(x, /)>

# %%
round
# Out:
# <function round(number, ndigits=None)>

# %%
round(3.1415, 2)
# Out:
# 3.14

# %% [markdown]
# ## 1.4 Strings

# %% [markdown]
# A string is a sequence of characters that are delimted by quotation marks (either single or double)
#
# myStr = "This is my string #$%^&"

# %%
'Hello'
# Out:
# 'Hello'

# %%
"it's a small world"
# Out:
# "it's a small world"

# %% [markdown]
# ### The + symbol with Strings

# %% [markdown]
# Concatination symbol + - The sign concatinates (connects together) two strings

# %%
"Well, " + "it's a small world" + " after all."
# Out:
# "Well, it's a small world after all."

# %% [markdown]
# ### Strings and the * operator

# %% [markdown]
# The * operator works with strings by making copies of a string and concatenates them together.

# %%
"Spam, " * 4
# Out:
# 'Spam, Spam, Spam, Spam, '

# %% [markdown]
# ### Strings and the len() function

# %%
len("String")
# Out:
# 6

# %%
len("Words Words even more Words")
# Out:
# 27

# %% [markdown]
# ## 1.5 Values and types

# %% [markdown]
# type() function - Python will tell you what type of data something is

# %%
type(42)
# Out:
# int

# %%
type(42.)
# Out:
# float

# %%
# int() function - changes a valid floating point number into an integer

int(42.5)
# Out:
# 42

# %%
# float() function - changes a valid integer to a floating-point number
float(42)
# Out:
# 42.0

# %%
'126'
# Out:
# '126'

# %%
type('126')
# Out:
# str

# %%
'126' / 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 '126' / 3
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
int('126') / 3
# Out:
# 42.0

# %%
1,000,000
# Out:
# (1, 0, 0)

# %%
1_000_000
# Out:
# 1000000

# %% [markdown]
# ### Natural Language
#
# are languages people speak, link English, Spanish, and French. The were not technically designed by people, naturally evolved from human speach.

# %% [markdown]
# ### Formal Language
#
# are languages that are designed by people for specific applications. For example, the notation that mathematicians use a formal language that is particularly good at denoting relationships amoung numbers and symbols.
#
# ### Debugging
#
# Mistakes made in the process of programming have been come to be known as bugs. Tracking down and fixing those mistakes then became debugging.
